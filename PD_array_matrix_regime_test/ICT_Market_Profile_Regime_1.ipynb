# %%
import pandas as pd
from tvDatafeed import TvDatafeed, Interval

# Step 1: Initialize tvDatafeed (use nologin for simplicity)
tv = TvDatafeed()

# Step 2: Define instruments to scan (symbol, exchange pairs)
instruments = [
    {'symbol': 'EURUSD', 'exchange': 'OANDA'},
    {'symbol': 'NAS100USD', 'exchange': 'OANDA'},
    {'symbol': 'WTICOUSD', 'exchange': 'OANDA'},
    {'symbol': 'CORNUSD', 'exchange': 'OANDA'},
    {'symbol': 'USDCAD', 'exchange': 'OANDA'},
    {'symbol': 'XAUUSD', 'exchange': 'OANDA'},
]

# Step 3: Fetch data for multiple instruments
def get_data(symbol, exchange, interval=Interval.in_1_hour, n_bars=1000):
    try:
        df = tv.get_hist(symbol=symbol, exchange=exchange, interval=interval, n_bars=n_bars)
        if df is None or df.empty:
            print(f"No data for {symbol}:{exchange}")
            return None
        # Exclude current day
        df = df.iloc[:-1]
        return df
    except Exception as e:
        print(f"Error fetching data for {symbol}:{exchange}: {e}")
        return None

# Step 4: Identify swing points (default 3-bar pattern)
def find_swings(df, window=3):
    df['swing_low'] = df['low'].rolling(window, center=True).min() == df['low']
    df['swing_high'] = df['high'].rolling(window, center=True).max() == df['high']
    return df

# Step 5: Classify trends based on swing points
def classify_trend(df, min_swings=2):
    df['regime'] = 'consolidation'
    if df is None or df.empty:
        return df, 'consolidation'

    # Get swing points
    swing_lows = df[df['swing_low']][['low']].reset_index().rename(columns={'low': 'price', 'datetime': 'timestamp'})
    swing_lows['type'] = 'low'
    swing_highs = df[df['swing_high']][['high']].reset_index().rename(columns={'high': 'price', 'datetime': 'timestamp'})
    swing_highs['type'] = 'high'

    # Type 2 trends (independent swing highs/lows)
    type2_up_count = 0
    type2_down_count = 0
    last_low_price = float('-inf')
    last_high_price = float('inf')

    # Process Type 2 Uptrend (higher swing lows)
    for _, row in swing_lows.iterrows():
        curr_price = row['price']
        curr_ts = row['timestamp']
        if curr_price > last_low_price:
            type2_up_count += 1
            if type2_up_count >= min_swings:
                df.loc[curr_ts, 'regime'] = 'type2_uptrend'
        else:
            type2_up_count = 0
        last_low_price = curr_price

    # Process Type 2 Downtrend (lower swing highs)
    for _, row in swing_highs.iterrows():
        curr_price = row['price']
        curr_ts = row['timestamp']
        if curr_price < last_high_price:
            type2_down_count += 1
            if type2_down_count >= min_swings:
                df.loc[curr_ts, 'regime'] = 'type2_downtrend'
        else:
            type2_down_count = 0
        last_high_price = curr_price

    # Combine and sort swings for Type 1 trends and retracement checks
    swings = pd.concat([swing_lows, swing_highs]).sort_values('timestamp').reset_index(drop=True)
    type1_up_count = 0
    type1_down_count = 0
    swing_sequence = []
    last_high_price = float('-inf')
    last_low_price = float('inf')
    last_swing_type = None
    latest_swing_type = None
    last_two_swings = []  # Track last two swings for Type 1 retracement

    # Process Type 1 trends and track swing sequence
    for i in range(len(swings)):
        curr_ts, curr_type, curr_price = swings['timestamp'][i], swings['type'][i], swings['price'][i]
        swing_sequence.append((curr_ts, curr_type, curr_price))
        last_swing_type = latest_swing_type
        latest_swing_type = curr_type
        last_two_swings.append((curr_ts, curr_type, curr_price))
        if len(last_two_swings) > 2:
            last_two_swings.pop(0)

        # Check for Type 1 trend violations
        if curr_type == 'high':
            if type1_up_count >= min_swings and curr_price <= last_high_price:
                type1_up_count = 0  # Violation: lower or equal swing high
            if type1_down_count >= min_swings and curr_price >= last_high_price:
                type1_down_count = 0  # Violation: higher or equal swing high
            last_high_price = curr_price
        elif curr_type == 'low':
            if type1_up_count >= min_swings and curr_price <= last_low_price:
                type1_up_count = 0  # Violation: lower or equal swing low
            if type1_down_count >= min_swings and curr_price >= last_low_price:
                type1_down_count = 0  # Violation: higher or equal swing low
            last_low_price = curr_price

        # Check Type 1 trends (need at least 4 swings for a cycle)
        if len(swing_sequence) >= 4:
            # Type 1 Uptrend
            if (swing_sequence[-4][1] == 'high' and
                swing_sequence[-3][1] == 'low' and
                swing_sequence[-2][1] == 'high' and
                swing_sequence[-1][1] == 'low'):
                if (swing_sequence[-2][2] > swing_sequence[-4][2] and  # Higher high
                    swing_sequence[-1][2] > swing_sequence[-3][2]):   # Higher low
                    type1_up_count += 1
                    if type1_up_count >= min_swings:
                        df.loc[swing_sequence[-4][0]:swing_sequence[-1][0], 'regime'] = 'type1_uptrend'
                else:
                    type1_up_count = 0

            # Type 1 Downtrend
            if (swing_sequence[-4][1] == 'high' and
                swing_sequence[-3][1] == 'low' and
                swing_sequence[-2][1] == 'high' and
                swing_sequence[-1][1] == 'low'):
                if (swing_sequence[-2][2] < swing_sequence[-4][2] and  # Lower high
                    swing_sequence[-1][2] < swing_sequence[-3][2]):   # Lower low
                    type1_down_count += 1
                    if type1_down_count >= min_swings:
                        df.loc[swing_sequence[-4][0]:swing_sequence[-1][0], 'regime'] = 'type1_downtrend'
                else:
                    type1_down_count = 0

    # Determine current regime for summary
    latest_regime = 'consolidation'
    if type1_up_count >= min_swings:
        # Check for Type 1 uptrend retracement (latest swing is high, previous is low, both higher)
        if (len(last_two_swings) == 2 and
            last_two_swings[-1][1] == 'high' and
            last_two_swings[-2][1] == 'low' and
            last_two_swings[-1][2] > last_high_price and
            last_two_swings[-2][2] > last_low_price):
            latest_regime = 'type1_uptrend_retracement'
        else:
            latest_regime = 'type1_uptrend'
    elif type1_down_count >= min_swings:
        # Check for Type 1 downtrend retracement (latest swing is low, previous is high, both lower)
        if (len(last_two_swings) == 2 and
            last_two_swings[-1][1] == 'low' and
            last_two_swings[-2][1] == 'high' and
            last_two_swings[-1][2] < last_low_price and
            last_two_swings[-2][2] < last_high_price):
            latest_regime = 'type1_downtrend_retracement'
        else:
            latest_regime = 'type1_downtrend'
    elif type2_up_count >= min_swings and type2_down_count >= min_swings:
        latest_regime = 'type2_uptrend_and_downtrend'
    elif type2_up_count >= min_swings:
        # Check for Type 2 uptrend retracement (latest swing is high, previous is low)
        if latest_swing_type == 'high' and last_swing_type == 'low':
            latest_regime = 'type2_uptrend_retracement'
        else:
            latest_regime = 'type2_uptrend'
    elif type2_down_count >= min_swings:
        # Check for Type 2 downtrend retracement (latest swing is low, previous is high)
        if latest_swing_type == 'low' and last_swing_type == 'high':
            latest_regime = 'type2_downtrend_retracement'
        else:
            latest_regime = 'type2_downtrend'

    return df, latest_regime

# Step 6: Scan all instruments
def scan_instruments(instruments, interval=Interval.in_weekly, n_bars=100, swing_window=3):
    results = {}
    for instr in instruments:
        symbol = instr['symbol']
        exchange = instr['exchange']
        print(f"Processing {symbol}:{exchange}...")
        
        # Fetch data
        df = get_data(symbol, exchange, interval, n_bars)
        if df is None:
            continue

        # Identify swings
        df = find_swings(df, window=swing_window)

        # Classify trends
        df, latest_regime = classify_trend(df)

        # Filter to show only swing points
        swing_points = df[df['swing_low'] | df['swing_high']].copy()
        swing_points['swing_price'] = swing_points.apply(
            lambda row: row['high'] if row['swing_high'] else row['low'] if row['swing_low'] else None, axis=1
        )

        # Store results
        results[f"{symbol}:{exchange}"] = latest_regime

        # Print swing points only
        print(f"\n{symbol}:{exchange} Swing Points:")
        print(swing_points[['swing_low', 'swing_high', 'swing_price', 'regime']].reset_index().to_string(index=False))

    return results

# Step 7: Run the scan
swing_window = 3  # Default 3-bar pattern for swing detection
results = scan_instruments(instruments, swing_window=swing_window)

# Step 8: Print summary
print("\nMarket Regime Summary:")
for instr, regime in results.items():
    print(f"{instr}: {regime}")
# Out:
# WARNING:tvDatafeed.main:you are using nologin method, data you access may be limited
# Processing EURUSD:OANDA...
#
# EURUSD:OANDA Swing Points:
#            datetime  swing_low  swing_high  swing_price          regime
# 2023-06-18 17:00:00      False        True      1.10120   consolidation
# 2023-07-02 17:00:00       True       False      1.08336   consolidation
# 2023-07-16 17:00:00      False        True      1.12757   consolidation
# 2023-07-30 17:00:00       True       False      1.09122   type2_uptrend
# 2023-08-06 17:00:00      False        True      1.10652 type1_downtrend
# 2023-08-20 17:00:00       True       False      1.07658 type1_downtrend
# 2023-08-27 17:00:00      False        True      1.09456 type1_downtrend
# 2023-10-01 17:00:00       True       False      1.04485 type1_downtrend
# 2023-10-08 17:00:00      False        True      1.06399 type2_downtrend
# 2023-10-29 17:00:00       True       False      1.05166   consolidation
# 2023-11-26 17:00:00      False        True      1.10173   type1_uptrend
# 2023-12-03 17:00:00       True       False      1.07237   type1_uptrend
# 2023-12-24 17:00:00      False        True      1.11396   type1_uptrend
# 2023-12-31 17:00:00       True       False      1.08770   type1_uptrend
# 2024-02-11 17:00:00       True       False      1.06950   consolidation
# 2024-02-18 17:00:00      False        True      1.08885   consolidation
# 2024-03-03 17:00:00      False        True      1.09813   consolidation
# 2024-04-07 17:00:00      False        True      1.08851   consolidation
# 2024-04-14 17:00:00       True       False      1.06011   consolidation
# 2024-04-28 17:00:00      False        True      1.08126 type2_downtrend
# 2024-05-12 17:00:00      False        True      1.08951   consolidation
# 2024-06-23 17:00:00       True       False      19506.2   type2_uptrend
# 2024-07-07 17:00:00      False        True      20792.0   consolidation
# 2024-08-04 17:00:00       True       False      17248.4   consolidation
# 2024-08-18 17:00:00      False        True      19948.2   consolidation
# 2024-09-01 17:00:00       True       False      18309.8   consolidation
# 2024-09-22 17:00:00      False        True      20351.4   consolidation
# 2024-09-29 17:00:00       True       False      19645.2   type2_uptrend
# 2024-10-27 17:00:00       True       False      19910.9   type2_uptrend
# 2024-11-10 17:00:00      False        True      21250.3   type1_uptrend
# 2024-11-17 17:00:00       True       False      20318.0   type1_uptrend
# 2024-12-15 17:00:00       True        True      22135.4   type1_uptrend
# 2025-01-05 17:00:00      False        True      21734.5   consolidation
# 2025-01-12 17:00:00       True       False      20551.6   consolidation
# 2025-01-19 17:00:00      False        True      21972.4   consolidation
# 2025-01-26 17:00:00       True       False      20648.9   consolidation
# 2025-02-16 17:00:00      False        True      22248.0   consolidation
# 2025-03-09 17:00:00       True       False      19124.9   consolidation
# 2025-03-23 17:00:00      False        True      20363.2   consolidation
# 2025-04-06 17:00:00       True       False      16335.1   consolidation
# 2025-04-20 17:00:00       True       False      17592.4   consolidation
# Processing WTICOUSD:OANDA...
#
# WTICOUSD:OANDA Swing Points:
#            datetime  swing_low  swing_high  swing_price          regime
# 2023-06-18 17:00:00      False        True       72.565   consolidation
# 2023-06-25 17:00:00       True       False       66.947   consolidation
# 2023-08-06 17:00:00      False        True       84.924   type1_uptrend
# 2023-08-20 17:00:00       True       False       77.991   type1_uptrend
# 2023-09-24 17:00:00      False        True       95.501   type1_uptrend
# 2023-10-01 17:00:00       True       False       81.769   type1_uptrend
# 2023-10-15 17:00:00      False        True       91.405 type1_downtrend
# 2023-11-12 17:00:00       True       False       72.687 type1_downtrend
# 2023-11-26 17:00:00      False        True       79.794 type1_downtrend
# 2023-12-10 17:00:00       True       False       67.819 type1_downtrend
# 2023-12-24 17:00:00      False        True       76.050 type2_downtrend
# 2023-12-31 17:00:00       True       False       69.204   consolidation
# 2024-01-07 17:00:00      False        True       75.223 type2_downtrend
# 2024-01-28 17:00:00      False        True       79.250   consolidation
# 2024-02-04 17:00:00       True       False       71.384   type2_uptrend
# 2024-02-25 17:00:00       True        True       81.051   type2_uptrend
# 2024-03-10 17:00:00       True       False       76.885   type2_uptrend
# 2024-03-17 17:00:00      False        True       83.545   consolidation
# 2024-04-07 17:00:00      False        True       87.895   consolidation
# 2024-05-19 17:00:00       True       False       76.603   consolidation
# 2024-05-26 17:00:00      False        True       81.003   consolidation
# 2024-06-02 17:00:00       True       False       72.730   consolidation
# 2024-06-30 17:00:00      False        True       84.740   consolidation
# 2024-08-04 17:00:00       True       False       72.243   consolidation
# 2024-08-11 17:00:00      False        True       80.331   consolidation
# 2024-08-18 17:00:00       True       False       72.714   consolidation
# 2024-08-25 17:00:00      False        True       78.732 type2_downtrend
# 2024-09-08 17:00:00       True       False       65.650   consolidation
# 2024-09-29 17:00:00       True       False       67.113   consolidation
# 2024-10-06 17:00:00      False        True       79.093   consolidation
# 2024-10-13 17:00:00       True       False       69.097   type2_uptrend
# 2024-10-27 17:00:00       True       False       67.334   consolidation
# 2024-11-03 17:00:00      False        True       73.267   consolidation
# 2024-11-17 17:00:00       True        True       71.792 type2_downtrend
# 2024-12-01 17:00:00       True       False       67.107   consolidation
# 2024-12-08 17:00:00      False        True       71.410 type2_downtrend
# 2025-01-12 17:00:00      False        True       80.756   consolidation
# 2025-03-02 17:00:00       True       False       65.396   consolidation
# 2025-03-30 17:00:00      False        True       72.485   consolidation
# 2025-04-06 17:00:00       True       False       55.232   consolidation
# 2025-04-20 17:00:00      False        True       65.316 type2_downtrend
# Processing CORNUSD:OANDA...
#
# CORNUSD:OANDA Swing Points:
#            datetime  swing_low  swing_high  swing_price          regime
# 2023-06-18 17:00:00      False        True        7.142   consolidation
# 2023-07-09 17:00:00       True       False        5.238   consolidation
# 2023-07-23 17:00:00      False        True        6.176 type1_downtrend
# 2023-08-20 17:00:00       True        True        5.386 type1_downtrend
# 2023-09-17 17:00:00       True       False        4.900 type1_downtrend
# 2023-10-01 17:00:00      False        True        5.176 type2_downtrend
# 2023-10-15 17:00:00      False        True        5.246   consolidation
# 2023-11-12 17:00:00       True       False        4.688   consolidation
# 2023-11-26 17:00:00       True       False        4.620   consolidation
# 2023-12-03 17:00:00      False        True        4.852   consolidation
# 2023-12-17 17:00:00       True       False        4.615   consolidation
# 2024-01-14 17:00:00       True       False        4.326   consolidation
# 2024-01-21 17:00:00      False        True        4.493 type2_downtrend
# 2024-02-25 17:00:00       True       False        3.969   consolidation
# 2024-03-24 17:00:00      False        True        4.400 type2_downtrend
# 2024-03-31 17:00:00       True       False        4.179   consolidation
# 2024-04-14 17:00:00       True       False        4.199   type2_uptrend
# 2024-05-12 17:00:00       True        True        4.632   type2_uptrend
# 2024-05-26 17:00:00      False        True        4.616 type1_downtrend
# 2024-06-02 17:00:00       True       False        4.314 type1_downtrend
# 2024-06-09 17:00:00      False        True        4.548 type1_downtrend
# 2024-06-23 17:00:00       True       False        3.906 type1_downtrend
# 2024-07-14 17:00:00       True       False        3.833   consolidation
# 2024-07-21 17:00:00      False        True        4.042 type2_downtrend
# 2024-08-11 17:00:00       True       False        3.751   consolidation
# 2024-08-25 17:00:00       True       False        3.715   consolidation
# 2024-09-01 17:00:00      False        True        4.026 type2_downtrend
# 2024-09-08 17:00:00       True       False        3.853   consolidation
# 2024-09-29 17:00:00      False        True        4.242   consolidation
# 2024-10-13 17:00:00       True       False        3.917   type2_uptrend
# 2024-10-20 17:00:00      False        True        4.169   consolidation
# 2024-11-03 17:00:00      False        True        4.297   type1_uptrend
# 2024-11-24 17:00:00       True       False        4.117   type1_uptrend
# 2024-12-08 17:00:00      False        True        4.384   type1_uptrend
# 2025-03-30 17:00:00      False        True      1.44154 type2_downtrend
# Processing XAUUSD:OANDA...
#
# XAUUSD:OANDA Swing Points:
#            datetime  swing_low  swing_high  swing_price          regime
# 2023-06-25 17:00:00       True       False     1893.070   consolidation
# 2023-07-16 17:00:00      False        True     1987.530   consolidation
# 2023-08-20 17:00:00       True       False     1884.885   consolidation
# 2023-08-27 17:00:00      False        True     1953.055 type2_downtrend
# 2023-09-10 17:00:00       True       False     1901.050   consolidation
# 2023-09-17 17:00:00      False        True     1947.465 type2_downtrend
# 2023-10-01 17:00:00       True       False     1810.465   consolidation
# 2023-10-22 17:00:00      False        True     2009.565   type1_uptrend
# 2023-11-12 17:00:00       True       False     1931.685   type1_uptrend
# 2023-12-03 17:00:00      False        True     2148.990   type1_uptrend
# 2023-12-10 17:00:00       True       False     1973.090   type1_uptrend
# 2023-12-24 17:00:00      False        True     2088.545   consolidation
# 2024-01-14 17:00:00       True       False     2001.895   type2_uptrend
# 2024-01-28 17:00:00      False        True     2065.530 type2_downtrend
# 2024-02-11 17:00:00       True       False     1984.305   consolidation
# 2024-03-03 17:00:00      False        True     2195.235   type1_uptrend
# 2024-03-17 17:00:00       True       False     2146.155   type1_uptrend
# 2024-04-07 17:00:00      False        True     2431.590   type1_uptrend
# 2024-04-28 17:00:00       True       False     2277.345   type1_uptrend
# 2024-05-19 17:00:00      False        True     2450.125   type1_uptrend
# 2024-06-02 17:00:00       True        True     2387.785   type1_uptrend
# 2024-06-16 17:00:00      False        True     2368.765 type2_downtrend
# 2024-06-23 17:00:00       True       False     2293.690   type2_uptrend
# 2024-07-14 17:00:00      False        True     2483.740   consolidation
# 2024-07-21 17:00:00       True       False     2353.195   type2_uptrend
# 2024-07-28 17:00:00      False        True     2477.725   consolidation
# 2024-08-04 17:00:00       True       False     2364.390   type2_uptrend
# 2024-08-18 17:00:00      False        True     2531.765   type1_uptrend
# 2024-09-01 17:00:00       True       False     2471.915   type1_uptrend
# 2024-09-22 17:00:00      False        True     2685.640   type1_uptrend
# 2024-10-06 17:00:00       True       False     2604.390   type1_uptrend
# 2024-10-27 17:00:00      False        True     2790.170   consolidation
# 2024-11-10 17:00:00       True       False     2536.855   consolidation
# 2024-11-24 17:00:00      False        True     2721.420   consolidation
# 2024-12-08 17:00:00      False        True     2726.295   consolidation
# 2024-12-15 17:00:00       True       False     2583.915   consolidation
# 2024-12-29 17:00:00       True       False     2596.185   type2_uptrend
# 2025-02-23 17:00:00       True        True     2956.310   type2_uptrend
# 2025-04-06 17:00:00       True       False     2956.565   type2_uptrend
# 2025-04-20 17:00:00      False        True     3500.200   consolidation
#
# Market Regime Summary:
# EURUSD:OANDA: type2_uptrend
# NAS100USD:OANDA: consolidation
# WTICOUSD:OANDA: type2_downtrend
# CORNUSD:OANDA: consolidation
# USDCAD:OANDA: type2_downtrend
# XAUUSD:OANDA: type2_uptrend_retracement
